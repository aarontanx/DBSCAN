# %%
import own_dbscan
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Data from https://www.kaggle.com/mlg-ulb/creditcardfraud
# df = pd.read_csv('.//data/creditcard.csv')
df.shape
# Out:
# (284807, 31)

# %%
# For example purpose, will only take 4 feature and 10k rows
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
col_name = list(df.columns[2:6])
df_new = df[col_name].copy()
df_new = df_new[:10000]

# %%
scaler = StandardScaler()
scaler.fit(df_new)
df_scaled_array = scaler.transform(df_new)
df_scaled_array
# Out:
# array([[-0.27118512,  1.40633482,  0.77299176, -0.24679022],
#        [-0.01207745, -0.63824711,  0.12767871,  0.08996388],
#        [-1.24007707,  0.74794464,  0.08023474, -0.38617705],
#        ...,
#        [ 0.35370831,  1.23247104, -0.46642505, -0.80552174],
#        [ 0.91273226,  0.51881308, -0.64328811, -0.83758036],
#        [ 0.91991428,  0.90798824,  1.61244433, -0.3869324 ]])

# %%
df_scaled = pd.DataFrame(df_scaled_array)
df_scaled.columns = col_name

# %%
df_scaled
# Out:
#             V2        V3        V4        V5
# 0    -0.271185  1.406335  0.772992 -0.246790
# 1    -0.012077 -0.638247  0.127679  0.089964
# 2    -1.240077  0.747945  0.080235 -0.386177
# 3    -0.357147  0.765013 -0.782312  0.030510
# 4     0.455470  0.554267  0.096371 -0.305015
# ...        ...       ...       ...       ...
# 9995  0.240106 -0.717921  1.580838  0.420233
# 9996 -0.177713  0.099931  0.084878 -0.783539
# 9997  0.353708  1.232471 -0.466425 -0.805522
# 9998  0.912732  0.518813 -0.643288 -0.837580
# 9999  0.919914  0.907988  1.612444 -0.386932
#
# [10000 rows x 4 columns]

# %%
# corr_plot = sns.pairplot(data= df_scaled)

# %%
# g = sns.PairGrid(df_scaled)
# g.map_upper(plt.scatter)
# g.map_lower(sns.kdeplot)
# g.map_diag(sns.kdeplot, lw = 3, legend = False)

# %%
print("Determine how many cluster and separation of clusters")
n_clus, max_sil, labels_true = own_dbscan.compute_silhouette(df_scaled, 20)
# Out:
# Determine how many cluster and separation of clusters
# For n_clusters =  2 The average silhouette_score is :  0.2135041262480896
# For n_clusters =  3 The average silhouette_score is :  0.2058144103650936
# For n_clusters =  4 The average silhouette_score is :  0.2194098236657447
# For n_clusters =  5 The average silhouette_score is :  0.2533272062726637
# For n_clusters =  6 The average silhouette_score is :  0.26083340327125254
# For n_clusters =  7 The average silhouette_score is :  0.24874751041805326
# For n_clusters =  8 The average silhouette_score is :  0.2512854812392173
# For n_clusters =  9 The average silhouette_score is :  0.25584931721114007
# For n_clusters =  10 The average silhouette_score is :  0.2564483996207451
# For n_clusters =  11 The average silhouette_score is :  0.26000626414446276
# For n_clusters =  12 The average silhouette_score is :  0.2611394150876088
# For n_clusters =  13 The average silhouette_score is :  0.2472964896744941
# For n_clusters =  14 The average silhouette_score is :  0.23622210163721383
# For n_clusters =  15 The average silhouette_score is :  0.24162323466285202
# For n_clusters =  16 The average silhouette_score is :  0.2313166369103743
# For n_clusters =  17 The average silhouette_score is :  0.23479462164649167
# For n_clusters =  18 The average silhouette_score is :  0.23675495299675772
# For n_clusters =  19 The average silhouette_score is :  0.23436134261605115
# For n_clusters =  20 The average silhouette_score is :  0.2368489581371069
# Best n_cluster: 12. Best silhouette score: 0.2611394150876088

# %%
eps = list(np.linspace(1, 2.5, 15))
min_samples = list(np.arange(50, 250, 50))

# %%
df_results = own_dbscan.find_optimal(df_scaled, eps, min_samples, labels_true)
# Out:
# Loop through the EPS and min sample list to find optimal outlier size.
#
# Iteration 1
# eps=  1.0 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 433
# Homogeneity: 0.048
# Completeness: 0.508
# V-measure: 0.087
# Adjusted Rand Index: 0.03
# Percentage Outliers: 4.33 %
#
#
# Iteration 2
# eps=  1.0 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 619
# Homogeneity: 0.064
# Completeness: 0.524
# V-measure: 0.115
# Adjusted Rand Index: 0.043
# Percentage Outliers: 6.19 %
#
#
# Iteration 3
# eps=  1.0 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 695
# Homogeneity: 0.068
# Completeness: 0.507
# V-measure: 0.119
# Adjusted Rand Index: 0.047
# Percentage Outliers: 6.95 %
#
#
# Iteration 4
# eps=  1.0 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 867
# Homogeneity: 0.078
# Completeness: 0.498
# V-measure: 0.134
# Adjusted Rand Index: 0.058
# Percentage Outliers: 8.67 %
#
#
# Iteration 5
# eps=  1.1071428571428572 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 337
# Homogeneity: 0.044
# Completeness: 0.56
# V-measure: 0.081
# Adjusted Rand Index: 0.025
# Percentage Outliers: 3.37 %
#
#
# Iteration 6
# eps=  1.1071428571428572 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 479
# Homogeneity: 0.058
# Completeness: 0.568
# V-measure: 0.105
# Adjusted Rand Index: 0.035
# Percentage Outliers: 4.79 %
#
#
# Iteration 7
# eps=  1.1071428571428572 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 537
# Homogeneity: 0.061
# Completeness: 0.555
# V-measure: 0.11
# Adjusted Rand Index: 0.039
# Percentage Outliers: 5.37 %
#
#
# Iteration 8
# eps=  1.1071428571428572 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 662
# Homogeneity: 0.067
# Completeness: 0.519
# V-measure: 0.118
# Adjusted Rand Index: 0.046
# Percentage Outliers: 6.62 %
#
#
# Iteration 9
# eps=  1.2142857142857142 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 286
# Homogeneity: 0.04
# Completeness: 0.589
# V-measure: 0.076
# Adjusted Rand Index: 0.021
# Percentage Outliers: 2.86 %
#
#
# Iteration 10
# eps=  1.2142857142857142 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 363
# Homogeneity: 0.048
# Completeness: 0.584
# V-measure: 0.089
# Adjusted Rand Index: 0.027
# Percentage Outliers: 3.63 %
#
#
# Iteration 11
# eps=  1.2142857142857142 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 427
# Homogeneity: 0.054
# Completeness: 0.583
# V-measure: 0.099
# Adjusted Rand Index: 0.032
# Percentage Outliers: 4.27 %
#
#
# Iteration 12
# eps=  1.2142857142857142 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 478
# Homogeneity: 0.058
# Completeness: 0.57
# V-measure: 0.105
# Adjusted Rand Index: 0.035
# Percentage Outliers: 4.78 %
#
#
# Iteration 13
# eps=  1.3214285714285714 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 233
# Homogeneity: 0.036
# Completeness: 0.614
# V-measure: 0.068
# Adjusted Rand Index: 0.018
# Percentage Outliers: 2.33 %
#
#
# Iteration 14
# eps=  1.3214285714285714 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 298
# Homogeneity: 0.043
# Completeness: 0.61
# V-measure: 0.081
# Adjusted Rand Index: 0.023
# Percentage Outliers: 2.98 %
#
#
# Iteration 15
# eps=  1.3214285714285714 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 338
# Homogeneity: 0.047
# Completeness: 0.598
# V-measure: 0.087
# Adjusted Rand Index: 0.025
# Percentage Outliers: 3.38 %
#
#
# Iteration 16
# eps=  1.3214285714285714 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 383
# Homogeneity: 0.051
# Completeness: 0.598
# V-measure: 0.094
# Adjusted Rand Index: 0.029
# Percentage Outliers: 3.83 %
#
#
# Iteration 17
# eps=  1.4285714285714286 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 205
# Homogeneity: 0.033
# Completeness: 0.63
# V-measure: 0.063
# Adjusted Rand Index: 0.016
# Percentage Outliers: 2.05 %
#
#
# Iteration 18
# eps=  1.4285714285714286 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 247
# Homogeneity: 0.039
# Completeness: 0.634
# V-measure: 0.073
# Adjusted Rand Index: 0.019
# Percentage Outliers: 2.47 %
#
#
# Iteration 19
# eps=  1.4285714285714286 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 289
# Homogeneity: 0.043
# Completeness: 0.627
# V-measure: 0.081
# Adjusted Rand Index: 0.022
# Percentage Outliers: 2.89 %
#
#
# Iteration 20
# eps=  1.4285714285714286 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 312
# Homogeneity: 0.046
# Completeness: 0.63
# V-measure: 0.086
# Adjusted Rand Index: 0.024
# Percentage Outliers: 3.12 %
#
#
# Iteration 21
# eps=  1.5357142857142856 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 172
# Homogeneity: 0.029
# Completeness: 0.623
# V-measure: 0.055
# Adjusted Rand Index: 0.013
# Percentage Outliers: 1.72 %
#
#
# Iteration 22
# eps=  1.5357142857142856 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 210
# Homogeneity: 0.034
# Completeness: 0.627
# V-measure: 0.064
# Adjusted Rand Index: 0.016
# Percentage Outliers: 2.1 %
#
#
# Iteration 23
# eps=  1.5357142857142856 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 241
# Homogeneity: 0.039
# Completeness: 0.642
# V-measure: 0.073
# Adjusted Rand Index: 0.019
# Percentage Outliers: 2.41 %
#
#
# Iteration 24
# eps=  1.5357142857142856 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 270
# Homogeneity: 0.042
# Completeness: 0.642
# V-measure: 0.079
# Adjusted Rand Index: 0.021
# Percentage Outliers: 2.7 %
#
#
# Iteration 25
# eps=  1.6428571428571428 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 150
# Homogeneity: 0.027
# Completeness: 0.648
# V-measure: 0.051
# Adjusted Rand Index: 0.012
# Percentage Outliers: 1.5 %
#
#
# Iteration 26
# eps=  1.6428571428571428 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 181
# Homogeneity: 0.031
# Completeness: 0.647
# V-measure: 0.059
# Adjusted Rand Index: 0.014
# Percentage Outliers: 1.81 %
#
#
# Iteration 27
# eps=  1.6428571428571428 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 209
# Homogeneity: 0.034
# Completeness: 0.64
# V-measure: 0.065
# Adjusted Rand Index: 0.016
# Percentage Outliers: 2.09 %
#
#
# Iteration 28
# eps=  1.6428571428571428 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 232
# Homogeneity: 0.038
# Completeness: 0.645
# V-measure: 0.071
# Adjusted Rand Index: 0.018
# Percentage Outliers: 2.32 %
#
#
# Iteration 29
# eps=  1.75 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 131
# Homogeneity: 0.025
# Completeness: 0.683
# V-measure: 0.049
# Adjusted Rand Index: 0.01
# Percentage Outliers: 1.31 %
#
#
# Iteration 30
# eps=  1.75 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 163
# Homogeneity: 0.029
# Completeness: 0.66
# V-measure: 0.056
# Adjusted Rand Index: 0.013
# Percentage Outliers: 1.63 %
#
#
# Iteration 31
# eps=  1.75 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 183
# Homogeneity: 0.031
# Completeness: 0.645
# V-measure: 0.059
# Adjusted Rand Index: 0.014
# Percentage Outliers: 1.83 %
#
#
# Iteration 32
# eps=  1.75 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 201
# Homogeneity: 0.033
# Completeness: 0.643
# V-measure: 0.064
# Adjusted Rand Index: 0.016
# Percentage Outliers: 2.01 %
#
#
# Iteration 33
# eps=  1.8571428571428572 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 114
# Homogeneity: 0.023
# Completeness: 0.706
# V-measure: 0.045
# Adjusted Rand Index: 0.009
# Percentage Outliers: 1.14 %
#
#
# Iteration 34
# eps=  1.8571428571428572 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 146
# Homogeneity: 0.027
# Completeness: 0.68
# V-measure: 0.053
# Adjusted Rand Index: 0.012
# Percentage Outliers: 1.46 %
#
#
# Iteration 35
# eps=  1.8571428571428572 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 164
# Homogeneity: 0.03
# Completeness: 0.681
# V-measure: 0.058
# Adjusted Rand Index: 0.013
# Percentage Outliers: 1.64 %
#
#
# Iteration 36
# eps=  1.8571428571428572 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 170
# Homogeneity: 0.031
# Completeness: 0.678
# V-measure: 0.059
# Adjusted Rand Index: 0.014
# Percentage Outliers: 1.7 %
#
#
# Iteration 37
# eps=  1.9642857142857142 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 103
# Homogeneity: 0.022
# Completeness: 0.737
# V-measure: 0.043
# Adjusted Rand Index: 0.008
# Percentage Outliers: 1.03 %
#
#
# Iteration 38
# eps=  1.9642857142857142 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 129
# Homogeneity: 0.025
# Completeness: 0.691
# V-measure: 0.049
# Adjusted Rand Index: 0.01
# Percentage Outliers: 1.29 %
#
#
# Iteration 39
# eps=  1.9642857142857142 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 149
# Homogeneity: 0.028
# Completeness: 0.682
# V-measure: 0.054
# Adjusted Rand Index: 0.012
# Percentage Outliers: 1.49 %
#
#
# Iteration 40
# eps=  1.9642857142857142 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 159
# Homogeneity: 0.029
# Completeness: 0.673
# V-measure: 0.056
# Adjusted Rand Index: 0.013
# Percentage Outliers: 1.59 %
#
#
# Iteration 41
# eps=  2.071428571428571 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 93
# Homogeneity: 0.022
# Completeness: 0.772
# V-measure: 0.042
# Adjusted Rand Index: 0.008
# Percentage Outliers: 0.93 %
#
#
# Iteration 42
# eps=  2.071428571428571 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 110
# Homogeneity: 0.023
# Completeness: 0.725
# V-measure: 0.045
# Adjusted Rand Index: 0.009
# Percentage Outliers: 1.1 %
#
#
# Iteration 43
# eps=  2.071428571428571 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 129
# Homogeneity: 0.025
# Completeness: 0.695
# V-measure: 0.049
# Adjusted Rand Index: 0.01
# Percentage Outliers: 1.29 %
#
#
# Iteration 44
# eps=  2.071428571428571 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 143
# Homogeneity: 0.027
# Completeness: 0.683
# V-measure: 0.052
# Adjusted Rand Index: 0.011
# Percentage Outliers: 1.43 %
#
#
# Iteration 45
# eps=  2.178571428571429 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 85
# Homogeneity: 0.02
# Completeness: 0.774
# V-measure: 0.039
# Adjusted Rand Index: 0.007
# Percentage Outliers: 0.85 %
#
#
# Iteration 46
# eps=  2.178571428571429 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 102
# Homogeneity: 0.022
# Completeness: 0.738
# V-measure: 0.043
# Adjusted Rand Index: 0.008
# Percentage Outliers: 1.02 %
#
#
# Iteration 47
# eps=  2.178571428571429 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 117
# Homogeneity: 0.024
# Completeness: 0.709
# V-measure: 0.046
# Adjusted Rand Index: 0.009
# Percentage Outliers: 1.17 %
#
#
# Iteration 48
# eps=  2.178571428571429 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 124
# Homogeneity: 0.025
# Completeness: 0.697
# V-measure: 0.048
# Adjusted Rand Index: 0.01
# Percentage Outliers: 1.24 %
#
#
# Iteration 49
# eps=  2.2857142857142856 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 81
# Homogeneity: 0.019
# Completeness: 0.766
# V-measure: 0.037
# Adjusted Rand Index: 0.007
# Percentage Outliers: 0.81 %
#
#
# Iteration 50
# eps=  2.2857142857142856 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 93
# Homogeneity: 0.021
# Completeness: 0.77
# V-measure: 0.042
# Adjusted Rand Index: 0.008
# Percentage Outliers: 0.93 %
#
#
# Iteration 51
# eps=  2.2857142857142856 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 108
# Homogeneity: 0.023
# Completeness: 0.723
# V-measure: 0.044
# Adjusted Rand Index: 0.009
# Percentage Outliers: 1.08 %
#
#
# Iteration 52
# eps=  2.2857142857142856 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 115
# Homogeneity: 0.024
# Completeness: 0.712
# V-measure: 0.046
# Adjusted Rand Index: 0.009
# Percentage Outliers: 1.15 %
#
#
# Iteration 53
# eps=  2.392857142857143 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 73
# Homogeneity: 0.018
# Completeness: 0.81
# V-measure: 0.036
# Adjusted Rand Index: 0.006
# Percentage Outliers: 0.73 %
#
#
# Iteration 54
# eps=  2.392857142857143 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 84
# Homogeneity: 0.02
# Completeness: 0.786
# V-measure: 0.039
# Adjusted Rand Index: 0.007
# Percentage Outliers: 0.84 %
#
#
# Iteration 55
# eps=  2.392857142857143 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 95
# Homogeneity: 0.022
# Completeness: 0.77
# V-measure: 0.042
# Adjusted Rand Index: 0.008
# Percentage Outliers: 0.95 %
#
#
# Iteration 56
# eps=  2.392857142857143 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 107
# Homogeneity: 0.023
# Completeness: 0.734
# V-measure: 0.045
# Adjusted Rand Index: 0.009
# Percentage Outliers: 1.07 %
#
#
# Iteration 57
# eps=  2.5 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 70
# Homogeneity: 0.018
# Completeness: 0.835
# V-measure: 0.036
# Adjusted Rand Index: 0.006
# Percentage Outliers: 0.7 %
#
#
# Iteration 58
# eps=  2.5 min_samples =  100
# Estimated number of clusters: 1
# Estimated number of noise points 77
# Homogeneity: 0.019
# Completeness: 0.802
# V-measure: 0.037
# Adjusted Rand Index: 0.006
# Percentage Outliers: 0.77 %
#
#
# Iteration 59
# eps=  2.5 min_samples =  150
# Estimated number of clusters: 1
# Estimated number of noise points 84
# Homogeneity: 0.02
# Completeness: 0.786
# V-measure: 0.039
# Adjusted Rand Index: 0.007
# Percentage Outliers: 0.84 %
#
#
# Iteration 60
# eps=  2.5 min_samples =  200
# Estimated number of clusters: 1
# Estimated number of noise points 87
# Homogeneity: 0.021
# Completeness: 0.794
# V-measure: 0.041
# Adjusted Rand Index: 0.007
# Percentage Outliers: 0.87 %

# %%
df_results.sort_values('num_error', ascending = False)
# Out:
#   iteration       eps min_samples   error num_error  n_clusters
# 0         4  1.000000         200  0.0867       867         1.0
# 0         3  1.000000         150  0.0695       695         1.0
# 0         8  1.107143         200  0.0662       662         1.0
# 0         2  1.000000         100  0.0619       619         1.0
# 0         7  1.107143         150  0.0537       537         1.0
# 0         6  1.107143         100  0.0479       479         1.0
# 0        12  1.214286         200  0.0478       478         1.0
# 0         1  1.000000          50  0.0433       433         1.0
# 0        11  1.214286         150  0.0427       427         1.0
# 0        16  1.321429         200  0.0383       383         1.0
# 0        10  1.214286         100  0.0363       363         1.0
# 0        15  1.321429         150  0.0338       338         1.0
# 0         5  1.107143          50  0.0337       337         1.0
# 0        20  1.428571         200  0.0312       312         1.0
# 0        14  1.321429         100  0.0298       298         1.0
# 0        19  1.428571         150  0.0289       289         1.0
# 0         9  1.214286          50  0.0286       286         1.0
# 0        24  1.535714         200  0.0270       270         1.0
# 0        18  1.428571         100  0.0247       247         1.0
# 0        23  1.535714         150  0.0241       241         1.0
# 0        13  1.321429          50  0.0233       233         1.0
# 0        28  1.642857         200  0.0232       232         1.0
# 0        22  1.535714         100  0.0210       210         1.0
# 0        27  1.642857         150  0.0209       209         1.0
# 0        17  1.428571          50  0.0205       205         1.0
# 0        32  1.750000         200  0.0201       201         1.0
# 0        31  1.750000         150  0.0183       183         1.0
# 0        26  1.642857         100  0.0181       181         1.0
# 0        21  1.535714          50  0.0172       172         1.0
# 0        36  1.857143         200  0.0170       170         1.0
# 0        35  1.857143         150  0.0164       164         1.0
# 0        30  1.750000         100  0.0163       163         1.0
# 0        40  1.964286         200  0.0159       159         1.0
# 0        25  1.642857          50  0.0150       150         1.0
# 0        39  1.964286         150  0.0149       149         1.0
# 0        34  1.857143         100  0.0146       146         1.0
# 0        44  2.071429         200  0.0143       143         1.0
# 0        29  1.750000          50  0.0131       131         1.0
# 0        38  1.964286         100  0.0129       129         1.0
# 0        43  2.071429         150  0.0129       129         1.0
# 0        48  2.178571         200  0.0124       124         1.0
# 0        47  2.178571         150  0.0117       117         1.0
# 0        52  2.285714         200  0.0115       115         1.0
# 0        33  1.857143          50  0.0114       114         1.0
# 0        42  2.071429         100  0.0110       110         1.0
# 0        51  2.285714         150  0.0108       108         1.0
# 0        56  2.392857         200  0.0107       107         1.0
# 0        37  1.964286          50  0.0103       103         1.0
# 0        46  2.178571         100  0.0102       102         1.0
# 0        55  2.392857         150  0.0095        95         1.0
# 0        41  2.071429          50  0.0093        93         1.0
# 0        50  2.285714         100  0.0093        93         1.0
# 0        60  2.500000         200  0.0087        87         1.0
# 0        45  2.178571          50  0.0085        85         1.0
# 0        54  2.392857         100  0.0084        84         1.0
# 0        59  2.500000         150  0.0084        84         1.0
# 0        49  2.285714          50  0.0081        81         1.0
# 0        58  2.500000         100  0.0077        77         1.0
# 0        53  2.392857          50  0.0073        73         1.0
# 0        57  2.500000          50  0.0070        70         1.0

# %%
eps = 3
min_samples = 50
model = own_dbscan.model_generation(df_scaled, eps, min_samples, labels_true)
# Out:
# Selecting EPS: 3, min_samples: 50
# Running model with defined param.
# eps=  3 min_samples =  50
# Estimated number of clusters: 1
# Estimated number of noise points 50
# Homogeneity: 0.014
# Completeness: 0.842
# V-measure: 0.028
# Adjusted Rand Index: 0.004
# Percentage Outliers: 0.5 %

# %%
unique, counts = np.unique(model.labels_, return_counts=True)
np.asarray((unique, counts)).T
# Out:
# array([[  -1,   50],
#        [   0, 9950]], dtype=int64)

# %%
sample = df_scaled.copy()

# %%
sample['label'] = list(model.labels_)
sample['label'] = np.where(sample['label'] > -1, 'label', 'outlier')

# %%
outlier_plot = sns.pairplot(data = sample
                            , palette = ['lightblue', 'Red']
                            , hue = 'label', vars = col_name)

# %%
df_scaled
# Out:
#             V2        V3        V4        V5
# 0    -0.271185  1.406335  0.772992 -0.246790
# 1    -0.012077 -0.638247  0.127679  0.089964
# 2    -1.240077  0.747945  0.080235 -0.386177
# 3    -0.357147  0.765013 -0.782312  0.030510
# 4     0.455470  0.554267  0.096371 -0.305015
# ...        ...       ...       ...       ...
# 9995  0.240106 -0.717921  1.580838  0.420233
# 9996 -0.177713  0.099931  0.084878 -0.783539
# 9997  0.353708  1.232471 -0.466425 -0.805522
# 9998  0.912732  0.518813 -0.643288 -0.837580
# 9999  0.919914  0.907988  1.612444 -0.386932
#
# [10000 rows x 4 columns]

# %%
sample[sample['label'] != 'label']
# Out:
#              V2         V3        V4         V5    label
# 164   -9.476655  -5.695165  2.102636  -1.155990  outlier
# 210   -4.750242  -0.977979 -2.082637   6.525571  outlier
# 1388  -3.021595  -2.036147  1.412472  -8.202922  outlier
# 1632  -7.564311 -11.470849  3.989277 -27.091364  outlier
# 2178  -9.202024  -3.657655  2.365519  -3.730893  outlier
# 2453  -6.902199  -2.557299  1.106598  -2.795394  outlier
# 2464 -12.243137  -1.106676  2.448346   9.050019  outlier
# 2622  -2.256203  -3.439235  1.234699  -9.612571  outlier
# 2792  -7.814943   0.687725  1.964254   6.742478  outlier
# 4235  -8.451473   0.800284  0.241644   8.849764  outlier
# 4415  -5.747700  -0.072905 -0.493238   7.216450  outlier
# 5371  -9.235343   1.594816  1.998455   7.537626  outlier
# 5504  -5.333380   0.671488  2.417238   6.914281  outlier
# 5797  -7.125736  -0.350596 -0.582103   3.626006  outlier
# 6331   2.947761  -6.165983  4.448896   0.688750  outlier
# 6334   2.943653  -6.441977  4.221874   1.163320  outlier
# 6336   2.622896  -5.765014  4.034324   1.448805  outlier
# 6338   2.696429  -5.626306  4.012938   1.352994  outlier
# 6641   2.914181  -7.186776  4.937746   0.862106  outlier
# 6717   3.544068  -5.894594  3.772892   1.057415  outlier
# 6719   3.082070  -6.727405  4.532901   0.560240  outlier
# 6783  -9.346448  -4.445354  4.553037  -2.409572  outlier
# 6812 -19.817293  -3.439390  3.193799   5.873645  outlier
# 6899   4.261568  -7.384968  4.243513  -0.012101  outlier
# 6903   4.213597  -7.354639  4.254677  -0.015903  outlier
# 6905  -7.329291  -0.480129  2.396020   5.652576  outlier
# 6971  -0.017884  -4.655204  3.184752  -5.857014  outlier
# 7243  -1.445974  -0.690318  2.879195  -6.467366  outlier
# 7420  -9.435469   0.988306  2.080159  10.162236  outlier
# 7523  -6.154810   1.603938  0.137824   6.083978  outlier
# 7600  -7.447834  -2.662291  1.113154  -2.917145  outlier
# 7617 -10.635792  -3.534656  1.822647  -4.285432  outlier
# 8296   4.351137 -10.301992  6.066628  -1.389031  outlier
# 8312   2.777251  -5.722686  4.045339   1.475449  outlier
# 8335   2.950933  -9.240282  4.442333  -3.976010  outlier
# 8464   1.923309  -5.491291  2.484613   4.634001  outlier
# 8610 -26.672505   1.153321  7.076836  28.866678  outlier
# 8615   5.211456 -10.639962  5.789359  -1.707117  outlier
# 8617   2.995003  -7.283156  4.970148   0.984561  outlier
# 8625   2.783628  -5.829261  2.207344   4.315916  outlier
# 9035   5.148614 -12.606098  6.993714  -2.458467  outlier
# 9044   2.720786  -7.795397  3.411698   3.564565  outlier
# 9119 -10.497600  -2.133738  0.534765   3.022318  outlier
# 9179   3.779217 -10.326669  4.458762  -4.830197  outlier
# 9252   6.120047 -11.784254  5.780189  -2.586580  outlier
# 9258   3.050742  -8.196162  3.400049   3.262705  outlier
# 9487   6.056882 -13.750358  6.984604  -3.337651  outlier
# 9489   3.380617  -8.596918  3.388414   2.960916  outlier
# 9509   6.386694 -14.151108  6.972981  -3.639385  outlier
# 9512   3.710452  -8.997670  3.376787   2.659161  outlier
